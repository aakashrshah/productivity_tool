# %%
#Python Group Project by:

#Dingling Ji
#Gina Romero
#Saumya Shukla
#Zijun Yan

# %%
#Question 1: What your approach was for this project
    #We approached this project by analyzing all teammates data sets and picking the cleanest data with the least amount
    # of missing variables. We ended up chosing Zijun Yan's dataset of NYC Free Public Wifi.It was the cleanest data, and
    #contained information which was the most relevant. With this dataset, we wanted
    #to produce meaningful maps that would be useful to the public or anyone analyzing wifi in NYC. NYC is one of the most 
    #population dense cities, which means it has plenty of data on Wifi spots. As citizens that use free wifi where available, 
    #we decided that it would be helpful to map where these wifi areas are located throughout the five buroughs of NYC. 
    #Details on the reasons we chose our maps will be further decribed in question 3.

# %%
#Question 2: Main challenges faced
 # The main challenges our team faced was the actual coding of the maps. Creating a drop down for providers was
 # a challenge because it would not select just one provider and display that one provider's data on the map. We eventually
#figured out that there had to be an arragenement of 'True' and 'False' for it to work. We have marked this down in our code.
 # Another problem we faced was the sorting out of the latitude and longitude coordinates based on SSID(column in our dataset).
# The SSID stands for the Service Set IDentifier which is the name of the wireless network. 
 # Figuring out the top important SSID's was difficult because there were a total of 15. We plotted the graph considering
 #only 7 because these are the most frequent ones.

# %%
#Question 3: Why you chose the maps you did
#We chose to create three maps. The maps we chose
#were purposely created to have meaning and be helpful to anyone
#looking for Wifi services in the NYC area. The first map gives 
#you the option to choose one of the five NYC buroughs and filter 
#by what type of wifi service is provided. This map is useful to the public
#because someone looking for wifi can search their borough, or whichever
#burough they wil be in, and drill down to which places have free wifi 
#they could use. If they hover over the point they will get the latitude and longitude
#and the street name of where there is free wifi. An analysis and further
#details of each map will be explained in the markdowns. 
#The second map we created is for the user to filter down on the borough and
#the internet provider. If a user prefers one internet provider over another, for example 
#At&T over another internet provider, then they can search for that internet provider’s
#location. This map can also be used by providers themselves if they want to analyze
#in which areas their internet services are and where they should be added or removed.
#For example, if their wifi competition has 30 locations in Staten Island, but they only have 5. Then 
#perhaps they will want to increase their number to match their competitor. 
# In the third map, users can filter by SSID and borough. 
#The SSID is the wireless network name. This map is not meant for users as most
#people don’t care about wireless network names, but this can be beneficial for 
#a company to keep track of where their networks are located.

# %%
#Question 4: How this experience compared to the R and leaflet project
# It was a group consensus that coding in Python for this project 
#was more challenging than R. For example, we felt adding 
#additional features to the maps was difficult as we kept getting
#errors. Python coding differed in that we did not have the
#ui or server tabs that we had to go back and forth on. Python coding
# for this project could all be done on the same cell. 
# Aside from the coding, the experience itself was different as we 
#also ran into problems being creative with our maps
#in Python. For our R project, we only did one map. The rest of our 
# R project was adding features of either plots, data analysis, or extra widgets. 
#This project made us think outside the box and analyze the columns of the data
#to decide which data could be meaningfully used. This project was not about creating
#one map, but a few maps. Each map had to be different and serve a purpose. 
#This project proved to us to be more challenging because we were not just coding
#to show a map, but we had to do some business analysis on the types of maps we would
#use and why. We had to brainstorm on what users would like to see from these maps so
#that they could use it for their benefit. 

#Below is the code for our three maps.

# %%
#Code for the first map that will feature the type of Wifi services available within the NYC boroughs.
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from plotly.graph_objs import *
init_notebook_mode(connected=True)
import pandas as pd
import numpy as np
#The colors of the legend 
cnames = ['#5cc476','#c93cd8','#0d4dd8']
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Read the data file
df = pd.read_csv('C:/Users/Saumya/Desktop/GWU/DNSC 6211- Programming for Analytics/Python/python project/python project NYC WIFI.csv', header=0, usecols=['TYPE', 'LOCATION', 'LAT', 'LON', 'BORONAME'])
#Display the first 5 rows and 5 columns of the data in a dataframe
df.head()
# Out:
#    TYPE            LOCATION       LAT      LON   BORONAME
# 0  Free  179 WEST 26 STREET  40.74597 -73.9940  Manhattan
# 1  Free   25 EAST 29 STREET  40.74461 -73.9851  Manhattan
# 2  Free       1515 BROADWAY  40.75767 -73.9859  Manhattan
# 3  Free  201 WEST 48 STREET  40.75997 -73.9843  Manhattan
# 4  Free       1600 Broadway  40.76041 -73.9845  Manhattan

# %%
# This data contains the five Borough names of NYC. For this data these Bouroughs are labeled Boronames. 
TYPE = df['TYPE'].unique()
BORONAME = df['BORONAME'].unique()

# %%
#The initial map is built with the general area latitude and longitude of NYC, the amount of zoom, the hovering feature,
#the colors from above, and the layout. The hovering will include the latitude, longitude, and any text on a
#point on the map.
#The legend and filters will later be added.
data = []
for i in range(len(TYPE)):
    data.append(Scattermapbox(
                lat=list(df[df['TYPE'] == TYPE[i]]['LAT']),
                lon=list(df[df['TYPE'] == TYPE[i]]['LON']),
                mode='markers',
                hoverinfo="lat+lon+text",
                text=list(df[df['TYPE'] == TYPE[i]]['LOCATION']),
                # opacity=0.5,
                marker=Marker(
                    size=6,
                    color=cnames[i]
                ),
                name=TYPE[i]
            ))

def update_graph():
    zoom = 10.0
    latInitial = 40.7119
    lonInitial = -73.9406  # -73.991251
    bearing = 0
    mapbox_access_token = 'pk.eyJ1IjoiYWxpc2hvYmVpcmkiLCJhIjoiY2ozYnM3YTUxMDAxeDMzcGNjbmZyMmplZiJ9.ZjmQ0C2MNs1AzEBC_Syadg'
#Creates the legend that shows Wifi type. This legend will also be used as a filter on the map. If you double click on
#one of the legend names, you can select all in the legend.
    return go.Figure(
        data=data,
        layout=Layout(
            showlegend=True,
            autosize=True,
            height=750,
            margin=Margin(l=0, r=0, t=0, b=0),
            mapbox=dict(
                accesstoken=mapbox_access_token,
                center=dict(
                    lat=latInitial,  # 40.7272
                    lon=lonInitial  # -73.991251
                ),
                style='light',
                bearing=bearing,
                zoom=zoom
            ),
            #Create the "Reset Zoom" button. This feature will reset the map to its original format.
            updatemenus=[
                 dict(
                     buttons=([
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-74.0060',
                                 'mapbox.center.lat': '40.7128',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                                 }],
                             label='reset zoom',
                             method='relayout'
                            )
                     ]),
                     direction='left',
                     pad={'r': 0, 't': 0, 'b': 0, 'l': 0},
                     showactive=False,
                     type='buttons',
                     x=0.45,
                     xanchor='left',
                     yanchor='bottom',
                     bgcolor='#323130',
                     borderwidth=1,
                     bordercolor='#efe9a0',
                     font=dict(
                        color='#e0d76b'
                    ),
                    y=0.02
                 ),
                #Create the burough names that will be shown on the map based on their latitudes and longitudes. It also
                #has the amount of zoom.
                 dict(
                     buttons=([
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.9712',
                                 'mapbox.center.lat': '40.7831',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Manhattan',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.8648',
                                 'mapbox.center.lat': '40.8448',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Bronx',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.9442',
                                 'mapbox.center.lat': '40.6782',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Brooklyn',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.7949',
                                 'mapbox.center.lat': '40.7282',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Queens',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-74.1502',
                                 'mapbox.center.lat': '40.5795',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Staten Island',
                             method='relayout'
                         )]),
                     #The area of the map where the burough names will be displayed, which is the top left.
                     direction='right',
                     x = 0.02,
                     xanchor = 'left',
                     y = 0.98,
                     yanchor = 'top',
                     bgcolor = '#edf5f7',
                     bordercolor = '#c586d8',
                     font = dict(size=12)
                 )
             ],
        )
    )

# %%
#Plot the map named fig
fig = update_graph()
iplot(fig)
# The map created below is a city map of NYC; the NYC burough names are displayed along the top of the map. If the Manhattan button
#is selected, more burough  names will appear. This means the data on the map can be viewed 
#by Burough name. On the right hand side of the map is the legend. There are three wifi types
#in the legend. This legend is also used as a filter for wifi type. For example, you can filter by Free wifi. If you double click
#on any name on the legend, you can select all on the legend.
#Each point on the map can be hovered over, and the latitude and longitude with text will show.  
#In summary, this map contains two filters: one filter for boronames, and another filter for Wifi type.
# Out:
# <div id="cae899b9-e995-4779-8871-1f673c908348" style="height: 750px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cae899b9-e995-4779-8871-1f673c908348", [{"type": "scattermapbox", "lat": [40.74597, 40.744609999999994, 40.757670000000005, 40.75997, 40.76041, 40.76259, 40.76088, 40.76063, 40.752340000000004, 40.75083, 40.749829999999996, 40.74973, 40.75865, 40.76072, 40.76247, 40.76027, 40.76024, 40.761509999999994, 40.760529999999996, 40.73611, 40.73415, 40.761140000000005, 40.75255, 40.74912, 40.74672, 40.74988, 40.762209999999996, 40.75674, 40.74791, 40.751540000000006, 40.75779, 40.76342, 40.76421, 40.76215, 40.745129999999996, 40.7609, 40.745129999999996, 40.760329999999996, 40.739979999999996, 40.75695, 40.748290000000004, 40.75267, 40.749340000000004, 40.75096, 40.748909999999995, 40.75118, 40.7532, 40.75013, 40
# ...

# %%
#Analysis: Based on the first map above, we see that Manhattan has the most free wifi spots of the five buroughs. Manhattan
#is also the onl burough with Partner Site wifi. Staten Island has the least amount of wifi spots. If a person 
#in Staten Island was in need of wifi, they could find free wifi at 56 Giffords Lane.

# %%
#Code for the second map that will feature the internet providers within the NYC buroughs.
#This map will show the internet providers in a dropdown box. It will also have a legend of burough names that
#can be used as a filter. 

#Create the initial map with latitude and longitude with the amount of zoom

mapbox_access_token = 'pk.eyJ1IjoiZGppMiIsImEiOiJjamdqdmgwczgwamFqMndxdW12dXJraG9wIn0.2Yz7iIjOam31JRldPG7g7A'

zoom = 10.0
latInitial = 40.724481
lonInitial = -73.840317
bearing = 0

#Read the data file
df = pd.read_csv('C:/Users/Saumya/Desktop/GWU/DNSC 6211- Programming for Analytics/Python/python project/python project NYC WIFI.csv')#'https://raw.githubusercontent.com/plotly/datasets/master/Nuclear%20Waste%20Sites%20on%20American%20Campuses.csv')

#Define the New York Buroughs
Bronx_df = df.loc[df['CITY'].isin(['Bronx'])]
Staten_Island_df = df.loc[df['CITY'].isin(['Staten Island'])]
Brooklyn_df = df.loc[df['CITY'].isin(['Brooklyn'])]
New_York_df = df.loc[df['CITY'].isin(['New York'])]
Queens_df = df.loc[df['CITY'].isin(['Queens'])]

#Define the Providers
ALTICEUSA_df = df.loc[df['PROVIDER'].isin(['ALTICEUSA'])]
AT_T_df = df.loc[df['PROVIDER'].isin(['AT&T'])]
BPL_df = df.loc[df['PROVIDER'].isin(['BPL'])]
Chelsea_df = df.loc[df['PROVIDER'].isin(['Chelsea'])]
City_Tech_df = df.loc[df['PROVIDER'].isin(['City Tech'])]
Downtown_Brooklyn_df = df.loc[df['PROVIDER'].isin(['Downtown Brooklyn'])]
Harlem_df = df.loc[df['PROVIDER'].isin(['Harlem'])]
LinkNYC_Citybridge_df = df.loc[df['PROVIDER'].isin(['LinkNYC - Citybridge'])]
Manhattan_Down_Alliance_df = df.loc[df['PROVIDER'].isin(['Manhattan Down Alliance'])]
NYCHA_df = df.loc[df['PROVIDER'].isin(['NYCHA'])]
NYPL_df = df.loc[df['PROVIDER'].isin(['NYPL'])]
QPL_df = df.loc[df['PROVIDER'].isin(['QPL'])]
SPECTRUM_df = df.loc[df['PROVIDER'].isin(['SPECTRUM'])]
Transit_Wireless_df = df.loc[df['PROVIDER'].isin(['Transit Wireless'])]
#Define the latitude and longitude of NYC
ny_site_lat = New_York_df.LAT
ny_site_lon = New_York_df.LON
#Define the latitude and longitude of Brooklyn
Brooklyn_site_lat = Brooklyn_df.LAT
Brooklyn_site_lon = Brooklyn_df.LON
#Define the latitude and longitude of Queens
Queens_site_lat = Queens_df.LAT
Queens_site_lon = Queens_df.LON
#Define the latitude and longitude of Bronx
Bronx_site_lat = Bronx_df.LAT
Bronx_site_lon = Bronx_df.LON

#Define the latitude and longitude of Staten Island
Staten_Island_site_lat = Staten_Island_df.LAT
Staten_Island_site_lon = Staten_Island_df.LON
#Define the latitude and longitude of Provider ALTICEUSA
ALTICEUSA_site_lat = ALTICEUSA_df.LAT
ALTICEUSA_site_lon = ALTICEUSA_df.LON
#Define the latitude and longitude of Provider AT&T
AT_T_df_site_lat = AT_T_df.LAT
AT_T_df_site_lon = AT_T_df.LON
#Define the latitude and longitude of Provider BPL
BPL_df_site_lat = BPL_df.LAT
BPL_df_site_lon = BPL_df.LON
#Define the latitude and longitude of Provider Chelsea
Chelsea_df_site_lat = Chelsea_df.LAT
Chelsea_df_site_lon = Chelsea_df.LON

#Define the latitude and longitude of Provider City Tech
City_Tech_df_site_lat = City_Tech_df.LAT
City_Tech_df_site_lon = City_Tech_df.LON

#Define the latitude and longitude of Provider Downtown Brooklyn
Downtown_Brooklyn_df_site_lat = Downtown_Brooklyn_df.LAT
Downtown_Brooklyn_df_site_lon = Downtown_Brooklyn_df.LON
#Define the latitude and longitude of Provider Link NYC
LinkNYC_Citybridge_df_site_lat = LinkNYC_Citybridge_df.LAT
LinkNYC_Citybridge_df_site_lon = LinkNYC_Citybridge_df.LON
#Define the latitude and longitude of Provider Manhattan Down Alliance
Manhattan_Down_Alliance_df_site_lat = Manhattan_Down_Alliance_df.LAT
Manhattan_Down_Alliance_df_site_lon = Manhattan_Down_Alliance_df.LON
#Define the latitude and longitude of Provider NYCHA
NYCHA_df_site_lat = NYCHA_df.LAT
NYCHA_df_site_lon = NYCHA_df.LON
#Define the latitude and longitude of Provider NYPL
NYPL_df_site_lat = NYPL_df.LAT
NYPL_df_site_lon = NYPL_df.LON
#Define the latitude and longitude of Provider QPL
QPL_df_site_lat = QPL_df.LAT
QPL_df_site_lon = QPL_df.LON
#Define the latitude and longitude of Provider Spectrum
SPECTRUM_df_site_lat = SPECTRUM_df.LAT
SPECTRUM_df_site_lon = SPECTRUM_df.LON
#Define the latitude and longitude of Provider Transit Wireless
Transit_Wireless_df_site_lat = Transit_Wireless_df.LAT
Transit_Wireless_df_site_lon = Transit_Wireless_df.LON
#Define the latitude and longitude of Provider Harlem
Harlem_df_site_lat = Harlem_df.LAT
Harlem_df_site_lon = Harlem_df.LON


locations_name = 'tmp'#df.text

#Define the markers of Queens by latitude and longitude
data = Data([
    Scattermapbox(
        lat=Queens_site_lat,
        lon=Queens_site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(169,169,169)',
            opacity=0.7
        ),
        text='Queens',
        hoverinfo='text'
    ),
    #Define the markers of Brooklyn by latitude and longitude
    Scattermapbox(
        lat=Brooklyn_site_lat,
        lon=Brooklyn_site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(105,105,105)',
            opacity=0.7
        ),
        text='Brooklyn',
        hoverinfo='text'
    ),
    #Define the markers of New York by latitude and longitude
    Scattermapbox(
        lat=ny_site_lat,
        lon=ny_site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(0, 0, 0)',
            opacity=0.7
        ),
        text='New York',
        hoverinfo='text'
    ),
    #Define the markers of Bronx by latitude and longitude
    Scattermapbox(
        lat=Bronx_site_lat,
        lon=Bronx_site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(128,128,128)',
            opacity=0.7
        ),
        text='Bronx',
        hoverinfo='text'
    ),
    #Define the markers of Staten Island by latitude and longitude
    Scattermapbox(
        lat=Staten_Island_site_lat,
        lon=Staten_Island_site_lon,
        mode='markers',
        marker=Marker(
            size=8,
            color='rgb(192,192,192)',
            opacity=0.7
        ),
        text='Staten Island',
        hoverinfo='text'
    ),
    #Define the markers of AlticeUSA by latitude and longitude
    Scattermapbox(
        lat=ALTICEUSA_site_lat,
        lon=ALTICEUSA_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(0, 128, 0)',
            opacity=0.23
        ),
        text='ALTICEUSA',
        hoverinfo='text'
    ),
    #Define the markers of AT&T by latitude and longitude
    Scattermapbox(
        lat=AT_T_df_site_lat,
        lon=AT_T_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(255, 0, 255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of BPL by latitude and longitude
    Scattermapbox(
        lat=BPL_df_site_lat,
        lon=BPL_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(255,255,0)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of Chelsea by latitude and longitude
    Scattermapbox(
        lat=Chelsea_df_site_lat,
        lon=Chelsea_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(255,0,0)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of City Tech by latitude and longitude
    Scattermapbox(
        lat= City_Tech_df_site_lat,
        lon= City_Tech_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(0,255,255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of Downtown Brooklyn by latitude and longitude
    Scattermapbox(
        lat= Downtown_Brooklyn_df_site_lat,
        lon= Downtown_Brooklyn_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(0,0,255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of Harlem by latitude and longitude
    Scattermapbox(
        lat= Harlem_df_site_lat,
        lon= Harlem_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(138,43,226)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of LinkNYC by latitude and longitude
    Scattermapbox(
        lat= LinkNYC_Citybridge_df_site_lat,
        lon= LinkNYC_Citybridge_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(255,192,203)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of Manhattan Down Alliance by latitude and longitude
    
    Scattermapbox(
        lat= Manhattan_Down_Alliance_df_site_lat,
        lon= Manhattan_Down_Alliance_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(139,69,19)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of NYCHA by latitude and longitude
    
    Scattermapbox(
        lat= NYCHA_df_site_lat,
        lon= NYCHA_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(255,0,255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    #Define the markers of NYPL by latitude and longitude
    Scattermapbox(
        lat= NYPL_df_site_lat,
        lon= NYPL_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(30,144,255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    
    #Define the markers of QPL by latitude and longitude
    Scattermapbox(
        lat= QPL_df_site_lat,
        lon= QPL_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(0,0,255)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
    
    #Define the markers of Transit Wireless by latitude and longitude
    Scattermapbox(
        lat= Transit_Wireless_df_site_lat,
        lon= Transit_Wireless_df_site_lon,
        mode='markers',
        marker=Marker(
            size=15,
            color='rgb(0,0,139)',
            opacity=0.23
        ),
        hoverinfo='none'
    ),
]
)
        
layout = Layout(
    autosize=True,
            height=750,
            margin=Margin(l=0, r=0, t=0, b=0),
            showlegend=False,
            mapbox=dict(
                accesstoken=mapbox_access_token,
                center=dict(
                    lat=latInitial, 
                    lon=lonInitial 
                ),
                style='light',
                bearing=bearing,
                zoom=zoom
            ),
    #Create the 'Reset Zoom' button. This feature will allow you to reset the zoom on the map to its original format.
            updatemenus=[
                dict(
                    buttons=([
                        dict(
                            args=[{
                                    'mapbox.zoom': 10,
                                    'mapbox.center.lon': '-73.840317',
                                    'mapbox.center.lat': '40.724481',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Reset Zoom',
                            method='relayout'
                        )
                    ]),
                    direction = 'left',
                    pad={'r': 0, 't': 0, 'b': 0, 'l': 0},
                    type = 'buttons',
                    x = 0.45,
                    xanchor = 'left',
                    y = 0.08,
                    yanchor = 'top',
                    bgcolor="rgb(255, 255, 255, 255)",
                    
                ),
                # The following will create the legend with the five NYC borough names.
                dict(
                    buttons=([
                        dict(
                            args=[{
                                    'mapbox.zoom': 11,
                                    'mapbox.center.lon': '-73.8811',
                                    'mapbox.center.lat': '40.66435',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Brooklyn',
                            method='relayout'
                        ),
                        dict(
                            args=[{
                                    'mapbox.zoom': 12,
                                    'mapbox.center.lon': '-73.8798',
                                    'mapbox.center.lat': '40.852171',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Bronx',
                            method='relayout'
                        ),
                        dict(
                            args=[{
                                    'mapbox.zoom': 12,
                                    'mapbox.center.lon': '-73.9845',
                                    'mapbox.center.lat': '40.77351',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='New York',
                            method='relayout'
                        ),
                        dict(
                            args=[{
                                    'mapbox.zoom': 12,
                                    'mapbox.center.lon': '-73.8753',
                                    'mapbox.center.lat': '40.72992',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Queens',
                            method='relayout'
                        ),
                        dict(
                            args=[{
                                    'mapbox.zoom': 12,
                                    'mapbox.center.lon': '-74.0758',
                                    'mapbox.center.lat': '40.60317',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Staten Island',
                            method='relayout'
                        ),
                        #Create the location of the legend for NYC borough names.
                    ]),
                    direction="down",
                    pad={'r': 0, 't': 0, 'b': 0, 'l': 0},
                    showactive=False,
                    bgcolor="rgb(255, 255, 255, 0)",
                    type='buttons',
                    yanchor='bottom',
                    xanchor='left',
                    font=dict(
                        color="#000000"
                    ),
                    x=0.89,
                    y=0.6
                ),
                #Create the dropdown menu for the internet providers. The first one created the 'All Provider' label, followed
                #by 'No Provider', then each individual provider like AT&T, Chelsea, etc. The True and False combination
                #allows for one provider to be selected at a time. There will be 16 items in the drop down. And all of 
                #the code is below
                
dict(
                    buttons=([
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='All PROVIDER',
                            method='update'
                        ),
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='NO PROVIDER',
                            method='update'
                        ),
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='ALTICEUSA',
                            method='update'
                        ),
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='AT&T',
                            method='update'
                        ),
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='BPL',
                            method='update'
                        ),
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Chelsea',
                            method='update'
                        ),
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='City Tech',
                            method='update'
                        ),
                         
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Downtown Brooklyn',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Harlem',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='LinkNYC - Citybridge',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Manhattan Down Alliance',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='NYCHA',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='NYPL',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='QPL',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='SPECTRUM',
                            method='update'
                        ),     
                        
                        dict(
                            args=[{
                                    'visible': [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True],
                                    'mapbox.zoom': 8,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Transit Wireless',
                            method='update'
                        ),          
                     #Create where on the map the dropdown selection of providers will be   
                    ]),
                    direction = 'down',
                    x = 0.3,
                    xanchor = 'right',
                    y = 0.95,
                    yanchor = 'bottom',
                    bgcolor = '#FFFFFF',
                    #bordercolor = '#000000',
                    font=dict(
                        color="#000000"
                    )
                ),
                
            ]
        
)

#Plot the map
fig = dict(data=data, layout=layout);
iplot(fig, filename='NYC_Free_Public_WiFi')

#The map below allows you to filter by provider via a drop down menu, and you can also select the
#NYC burough by clicking the name of the burough in the legend on the right side of the map. There is also a reset 
#zoom button, and hovering capabilities.
# Out:
# <div id="84d24759-c225-47ea-ba1c-45c70fd43235" style="height: 750px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("84d24759-c225-47ea-ba1c-45c70fd43235", [{"type": "scattermapbox", "lat": [40.73314, 40.73319, 40.742090000000005, 40.74199, 40.777, 40.7221, 40.7432, 40.71881, 40.72023, 40.7206, 40.72103, 40.71921, 40.70393, 40.70402, 40.70345, 40.70335, 40.70597, 40.70636, 40.702729999999995, 40.70377, 40.58656, 40.58654, 40.58467, 40.58455, 40.58461, 40.58473, 40.58305, 40.58291, 40.58282, 40.58296, 40.5831, 40.58056, 40.58047, 40.58056, 40.5807, 40.58035, 40.69705, 40.6979, 40.6981, 40.70469, 40.7039, 40.70584, 40.70185, 40.70183, 40.706509999999994, 40.70436, 40.70422, 40.70514, 40.704609999999995, 40.73121, 40.730540000000005, 40.73012, 40.73012, 40.72681, 40.72987, 40.73082, 40.73049, 40.728840000000005, 40.74726, 
# ...

# %%
#Analysis: For the second map above, we see that Staten Island does not have At&T as a wifi provider. This means a
#user preferring to use AT&T services would not go to Staten Island. At&T, as a company and provider, should consider
#having AT&T wifi service in Staten Island.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import matplotlib.patches as mpatches
from plotly.graph_objs import *
import numpy as np
init_notebook_mode(connected=True)
import pandas as pd
#Define the colors for the map and the SSID
colorcode = ['#3498DB','#884EA0','#A04000', '#F1C40F','#CB4335','#34495E','#ECF0F1']
#classes = ['attwifi','Downtown Brooklyn WiFi','GuestWiFi','Harlem Wi-Fi','LinkNYC Free Wi-Fi','TransitWirelessWiFi','unionsquarewifi']
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Read the data file and assign which columns will be used
#Link the Boroname to the SSID  in the data file and create the SSID legend and filters
df_wifi = pd.read_csv('C:/Users/Saumya/Desktop/GWU/DNSC 6211- Programming for Analytics/Python/python project/python project NYC WIFI.csv',usecols=['SSID', 'LAT', 'LON', 'BORONAME'])
SSID_filtered = ['attwifi','Downtown Brooklyn WiFi','GuestWiFi','Harlem Wi-Fi','LinkNYC Free Wi-Fi','TransitWirelessWiFi','unionsquarewifi']
df_wifi = df_wifi.loc[df_wifi['SSID'].isin(SSID_filtered)]
BORONAME = df_wifi['BORONAME'].unique()
SSID = df_wifi['SSID'].unique()
df_wifi.head()
# Out:
#         LAT      LON                SSID   BORONAME
# 0  40.74597 -73.9940  LinkNYC Free Wi-Fi  Manhattan
# 1  40.74461 -73.9851  LinkNYC Free Wi-Fi  Manhattan
# 2  40.75767 -73.9859  LinkNYC Free Wi-Fi  Manhattan
# 3  40.75997 -73.9843  LinkNYC Free Wi-Fi  Manhattan
# 4  40.76041 -73.9845  LinkNYC Free Wi-Fi  Manhattan

# %%
#The third map will filter the SSID within the NYC buroughs. This map is meant for the use of the network owners
#so they can analyze where their networks are been used and make strategic decions to remove or add networks. As for
#visualizations, this map can also be displayed in satellite view. 

#Create the format and layout of the map. Link SSID to Boroname and latitude and longitude
data = []
for i in range(len(SSID)):
    data.append(Scattermapbox(
                lat=list(df_wifi[df_wifi['SSID'] == SSID[i]]['LAT']),
                lon=list(df_wifi[df_wifi['SSID'] == SSID[i]]['LON']),
                mode='markers',
                hoverinfo="lat+lon+text",
                text=list(df_wifi[df_wifi['SSID'] == SSID[i]]['BORONAME']),
                marker=Marker(
                    size=6,
                    color=colorcode[i]
                ),
                name= SSID[i]
            ))


def update_graph():
    zoom = 12.0
    bearing= 0

    mapbox_access_token='pk.eyJ1Ijoic2F1bXlhMjYiLCJhIjoiY2pnbzl1c2tmMTMwejJ4cXNsa3ZyMWZuayJ9._Khhvv-YrQRe6tH8KsULDg'
  
    return go.Figure(
         
    data=data,


    layout=Layout(
            autosize=True,
            showlegend=True,
            height=750,
            margin=Margin(l=0, r=0, t=0, b=0),
            mapbox=dict(
                accesstoken=mapbox_access_token,
                center=dict(
                    lat=40.730610,
                    lon= -73.935242
                ),
                style='light',
                bearing=bearing,
                zoom=zoom
            ),
        #Create Reset Zoom Button
            updatemenus=[
                dict(
                    buttons=([
                        dict(
                            args=[{
                                    'mapbox.zoom': 12,
                                    'mapbox.center.lon': '-73.991251',
                                    'mapbox.center.lat': '40.7272',
                                    'mapbox.bearing': 0,
                                    'mapbox.style': 'light'
                                }],
                            label='Reset Zoom',
                            method='relayout'
                        )
                    ]),
                    direction='left',
                    pad={'r': 0, 't': 0, 'b': 0, 'l': 0},
                    showactive=False,
                    type='buttons',
                    x=0.45,
                    xanchor='left',
                    yanchor='bottom',
                    bgcolor='#323130',
                    borderwidth=1,
                    bordercolor="#6d6d6d",
                    font=dict(
                        color="#FFFFFF"
                    ),
                    y=0.02
                ),
                #Create the NYC Burough legend and filter. Also allow hovering feature to include lattitude, longitude, 
                #and burough name. 
                dict(
                    buttons=([
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.9712',
                                 'mapbox.center.lat': '40.7831',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Manhattan',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.8648',
                                 'mapbox.center.lat': '40.8448',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Bronx',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.9442',
                                 'mapbox.center.lat': '40.6782',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Brooklyn',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-73.7949',
                                 'mapbox.center.lat': '40.7282',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Queens',
                             method='relayout'
                         ),
                         dict(
                             args=[{
                                 'mapbox.zoom': 12,
                                 'mapbox.center.lon': '-74.1502',
                                 'mapbox.center.lat': '40.5795',
                                 'mapbox.bearing': 0,
                                 'mapbox.style': 'light'
                              }],
                             label='Staten Island',
                             method='relayout'
                         )]),
                    direction="down",
                    pad={'r': 0, 't': 0, 'b': 0, 'l': 0},
                    showactive=False,
                    bgcolor="rgb(50, 49, 48, 0)",
                    type='buttons',
                    yanchor='bottom',
                    xanchor='left',
                    font=dict(
                        color="#FFFFFF"
                    ),
                    x=0,
                    y=0.05
                ),
                #Create the map visualizations of satellite view, dark view, light view, and satellite
                #with streets.
    dict(
        buttons=list([
            dict(
                args=['mapbox.style', 'dark'],
                label='Dark',
                method='relayout'
            ),                    
            dict(
                args=['mapbox.style', 'light'],
                label='Light',
                method='relayout'
            ),
            dict(
                args=['mapbox.style', 'satellite'],
                label='Satellite',
                method='relayout'
            ),
            dict(
                args=['mapbox.style', 'satellite-streets'],
                label='Satellite with Streets',
                method='relayout'
            )                    
        ]),
        direction = 'up',
        x = 0.75,
        xanchor = 'left',
        y = 0.05,
        yanchor = 'bottom',
        bgcolor = '#ffffff',
        bordercolor = '#000000',
        font = dict(size=11)
    )
   ],
    annotations = list([
    dict(text='Change Map Theme', font=dict(color='white',size=12), borderpad=10, 
         x=0.94, y=0.10, xref='page', yref='page', align='right', showarrow=False, bgcolor='black'),
    dict(text='NYC AREAS', font=dict(color='white',size=12), borderpad=10, 
         x=0.004, y=0.28, xref='page', yref='page', align='right', showarrow=False, bgcolor='black')
])
 )
)

# %%
#Plot the map
figure = update_graph()
iplot(figure)
#The below map allows you to click on the SSID/Network Name in the legend on the right side. And you 
#can also filter by NYC burough. This map also features a satelite view. In the bottom right hand side of the 
#map,you can change the map theme to satellite view, dark view, light view, etc. This map also shows latitude
# longitude and burough name when a dot is hovered over. This map also features a reset zoom button.
# Out:
# <div id="8aeffe26-da68-4862-8349-9e0325f98442" style="height: 750px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8aeffe26-da68-4862-8349-9e0325f98442", [{"type": "scattermapbox", "lat": [40.74597, 40.744609999999994, 40.757670000000005, 40.75997, 40.76041, 40.76259, 40.76088, 40.76063, 40.752340000000004, 40.75083, 40.749829999999996, 40.74973, 40.75865, 40.76072, 40.76247, 40.76027, 40.76024, 40.761509999999994, 40.760529999999996, 40.73611, 40.73415, 40.761140000000005, 40.75255, 40.74912, 40.74672, 40.74988, 40.762209999999996, 40.75674, 40.74791, 40.751540000000006, 40.75779, 40.76342, 40.76421, 40.76215, 40.745129999999996, 40.7609, 40.745129999999996, 40.760329999999996, 40.739979999999996, 40.75695, 40.748290000000004, 40.75267, 40.749340000000004, 40.75096, 40.748909999999995, 40.75118, 40.7532, 40.75013, 40
# ...

# %%
#Analysis: Based on the third map above, the Network name that is most dominant in NYC, particularly
#Manhattan and Brooklyn is LinkNYC Free wifi.
#The second most popular network name in NYC is GuestWifi.
#This means that for a competitor looking to enter the market, they will know their largest competitor and
#the locations of the competition. 
#Staten Island has the least amount of networks of all the 5 buroughs.

# %%
#We undertake that everyone in the group contributed to this project.
#Dingling Ji
#Gina Romero
#Saumya Shukla
#Zijun Yan
